# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pylab import *

# %%
filen = "train.csv"
df = pd.read_csv(filen)
attr_1 = 'satisfaction_level'
attr_2 = 'last_evaluation'

#left
left_df = df['left']
# print left_df

left_0 = df[df['left']==0]
left_1 = df[df['left']==1]

work_df0 = left_0[attr_1]
work_df1 = left_1[attr_1]

rows0 = work_df0.shape[0]
print "rows in left=0: ",rows0,
lim=2000
ar0 = work_df0[:lim]
# ar0 = np.split(work_df0, 100)
rows1 = work_df1.shape[0]
print "rows in left=1: ",rows1
ar1 = work_df1[:lim]
print "ar0, ar1 ",ar0.shape[0],ar1.shape[0]

max0=ar0.max()
min0=ar0.min()
max1=ar1.max()
min1=ar1.min()

maxim=max(max1,max0)
minim=min(min0,min1)
print "max, min: ",maxim,minim
ar =[]
i=minim
while i<maxim:
#     print i
    ar.append(i)
    i=i+0.01
print ar
x = np.linspace(0,lim-1,lim)
fig, axes = plt.subplots(figsize=(10, 10))
axes.set_yticks(ar)
axes.scatter(x,ar0, label=r"$left=0$")
axes.scatter(x,ar1,label=r"$left=1$")
legend = axes.legend(loc='best')
axes.set_title('Satisfaction_level')


fig2, axes2 = plt.subplots(1, 2, figsize=(10,10))
axes2[0].set_yticks(ar)
axes2[1].set_yticks(ar)

axes2[0].scatter(x,ar0, label=r"$left=0$")
axes2[1].scatter(x,ar1,label=r"$left=1$",color="orange")
legend = axes2[0].legend(loc='best')
legend2 = axes2[1].legend(loc='best')

axes2[0].set_title('satisfaction, left=0')
axes2[1].set_title('satisfaction, left=1')
# Out:
# rows in left=0:  8563 rows in left=1:  2675
# ar0, ar1  2000 2000
# max, min:  1.0 0.09
# ...

# %%
filen = "train.csv"
df = pd.read_csv(filen)

#left
left_df = df['left']
# print left_df

left_0 = df[df['left']==0]
left_1 = df[df['left']==1]

work_df0 = left_0['last_evaluation']
work_df1 = left_1['last_evaluation']

rows0 = work_df0.shape[0]
print "rows in left=0: ",rows0,
# ar0 = np.split(work_df0, 100)
rows1 = work_df1.shape[0]
print "rows in left=1: ",rows1

lim=min(rows0-1,rows1-1)
ar0 = work_df0[:lim]
ar1 = work_df1[:lim]
print "ar0, ar1 ",ar0.shape[0],ar1.shape[0]

max0=ar0.max()
min0=ar0.min()
max1=ar1.max()
min1=ar1.min()

maxim=max(max1,max0)
minim=min(min0,min1)
print "max, min: ",maxim,minim
ar =[]
i=minim
while i<maxim:
#     print i
    ar.append(i)
    i=i+0.1
print "ticks: ",ar

x = np.linspace(0,lim-1,lim)
fig, axes = plt.subplots(figsize=(10, 10))
axes.set_yticks(ar)
axes.scatter(x,ar0, label=r"$left=0$")
axes.scatter(x,ar1,label=r"$left=1$")
legend = axes.legend(loc='best')
axes.set_title('last_evaluated')

fig2, axes2 = plt.subplots(1, 2, figsize=(10,10))
axes2[0].set_yticks(ar)
axes2[1].set_yticks(ar)

axes2[0].scatter(x,ar0, label=r"$left=0$")
axes2[1].scatter(x,ar1,label=r"$left=1$",color="orange")
legend = axes2[0].legend(loc='best')
legend2 = axes2[1].legend(loc='best')

axes2[0].set_title('last_eval, left=0')
axes2[1].set_title('last_eval, left=1')
# Out:
# rows in left=0:  8563 rows in left=1:  2675
# ar0, ar1  2674 2674
# max, min:  1.0 0.36
# ticks:  [0.36, 0.45999999999999996, 0.5599999999999999, 0.6599999999999999, 0.7599999999999999, 0.8599999999999999, 0.9599999999999999]
# Text(0.5,1,'last_eval, left=1')

# %%
filen = "train.csv"
df = pd.read_csv(filen)

#left
left_df = df['left']
# print left_df

left_0 = df[df['left']==0]
left_1 = df[df['left']==1]

work_df0 = left_0['number_project']
work_df1 = left_1['number_project']

rows0 = work_df0.shape[0]
print "rows in left=0: ",rows0,
# ar0 = np.split(work_df0, 100)
rows1 = work_df1.shape[0]
print "rows in left=1: ",rows1

lim=min(rows0-1,rows1-1)
ar0 = work_df0[:lim]
ar1 = work_df1[:lim]
print "ar0, ar1 ",ar0.shape[0],ar1.shape[0]

max0=ar0.max()
min0=ar0.min()
max1=ar1.max()
min1=ar1.min()

maxim=max(max1,max0)
minim=min(min0,min1)
print "max, min: ",maxim,minim
ar =[]
i=minim
while i<maxim:
#     print i
    ar.append(i)
    i=i+0.1
print "ticks: ",ar

x = np.linspace(0,lim-1,lim)
fig, axes = plt.subplots(figsize=(10, 10))
axes.set_yticks(ar)
axes.scatter(x,ar0, label=r"$left=0$")
axes.scatter(x,ar1,label=r"$left=1$")
legend = axes.legend(loc='best')
axes.set_title('number_project')

fig2, axes2 = plt.subplots(1, 2, figsize=(10,10))
axes2[0].set_yticks(ar)
axes2[1].set_yticks(ar)

axes2[0].scatter(x,ar0, label=r"$left=0$")
axes2[1].scatter(x,ar1,label=r"$left=1$",color="orange")
legend = axes2[0].legend(loc='best')
legend2 = axes2[1].legend(loc='best')

axes2[0].set_title('number_project, left=0')
axes2[1].set_title('number_project, left=1')
# Out:
# rows in left=0:  8563 rows in left=1:  2675
# ar0, ar1  2674 2674
# max, min:  7 2
# ticks:  [2, 2.1, 2.2, 2.3000000000000003, 2.4000000000000004, 2.5000000000000004, 2.6000000000000005, 2.7000000000000006, 2.8000000000000007, 2.900000000000001, 3.000000000000001, 3.100000000000001, 3.200000000000001, 3.300000000000001, 3.4000000000000012, 3.5000000000000013, 3.6000000000000014, 3.7000000000000015, 3.8000000000000016, 3.9000000000000017, 4.000000000000002, 4.100000000000001, 4.200000000000001, 4.300000000000001, 4.4, 4.5, 4.6, 4.699999999999999, 4.799999999999999, 4.899999999999999, 4.999999999999998, 5.099999999999998, 5.1999999999999975, 5.299999999999997, 5.399999999999997, 5.4999999999999964, 5.599999999999996, 5.699999999999996, 5.799999999999995, 5.899999999999995, 5.999999999999995, 6.099999999999994, 6.199999999999994, 6.299999999999994, 6.399999999999993, 6.499999999999993, 6.5999999999999925, 6.699999999999992, 6.799999999999992, 6.8999999999999915, 6.999999999999991]
# ...

# %%
filen = "train.csv"
df = pd.read_csv(filen)

#left
left_df = df['left']
# print left_df

left_0 = df[df['left']==0]
left_1 = df[df['left']==1]

work_df0 = left_0['average_montly_hours']
work_df1 = left_1['average_montly_hours']

rows0 = work_df0.shape[0]
print "rows in left=0: ",rows0,
# ar0 = np.split(work_df0, 100)
rows1 = work_df1.shape[0]
print "rows in left=1: ",rows1

lim=min(rows0-1,rows1-1)
ar0 = work_df0[:lim]
ar1 = work_df1[:lim]
print "ar0, ar1 ",ar0.shape[0],ar1.shape[0]

max0=ar0.max()
min0=ar0.min()
max1=ar1.max()
min1=ar1.min()

maxim=max(max1,max0)
minim=min(min0,min1)
print "max, min: ",maxim,minim
ar =[]
i=minim
while i<maxim:
#     print i
    ar.append(i)
    i=i+5
print "ticks: ",ar

x = np.linspace(0,lim-1,lim)
fig, axes = plt.subplots(figsize=(10, 10))
axes.set_yticks(ar)
axes.scatter(x,ar0, label=r"$left=0$")
axes.scatter(x,ar1,label=r"$left=1$")
legend = axes.legend(loc='best')
axes.set_title('average_montly_hours')

fig2, axes2 = plt.subplots(1, 2, figsize=(10,10))
axes2[0].set_yticks(ar)
axes2[1].set_yticks(ar)

axes2[0].scatter(x,ar0, label=r"$left=0$")
axes2[1].scatter(x,ar1,label=r"$left=1$",color="orange")
legend = axes2[0].legend(loc='best')
legend2 = axes2[1].legend(loc='best')

axes2[0].set_title('average_montly_hours, left=0')
axes2[1].set_title('average_montly_hours, left=1')
# Out:
# rows in left=0:  8563 rows in left=1:  2675
# ar0, ar1  2674 2674
# max, min:  310 96
# ticks:  [96, 101, 106, 111, 116, 121, 126, 131, 136, 141, 146, 151, 156, 161, 166, 171, 176, 181, 186, 191, 196, 201, 206, 211, 216, 221, 226, 231, 236, 241, 246, 251, 256, 261, 266, 271, 276, 281, 286, 291, 296, 301, 306]
# Text(0.5,1,'average_montly_hours, left=1')

# %%
filen = "train.csv"
df = pd.read_csv(filen)

#left
left_df = df['left']
# print left_df

left_0 = df[df['left']==0]
left_1 = df[df['left']==1]

work_df0 = left_0['time_spend_company']
work_df1 = left_1['time_spend_company']

rows0 = work_df0.shape[0]
print "rows in left=0: ",rows0,
# ar0 = np.split(work_df0, 100)
rows1 = work_df1.shape[0]
print "rows in left=1: ",rows1

lim=min(rows0-1,rows1-1)
ar0 = work_df0[:lim]
ar1 = work_df1[:lim]
print "ar0, ar1 ",ar0.shape[0],ar1.shape[0]

max0=ar0.max()
min0=ar0.min()
max1=ar1.max()
min1=ar1.min()

maxim=max(max1,max0)
minim=min(min0,min1)
print "max, min: ",maxim,minim
ar =[]
i=minim
while i<maxim:
#     print i
    ar.append(i)
    i=i+1
print "ticks: ",ar

x = np.linspace(0,lim-1,lim)
fig, axes = plt.subplots(figsize=(10, 10))
axes.set_yticks(ar)
axes.scatter(x,ar0, label=r"$left=0$")
axes.scatter(x,ar1,label=r"$left=1$")
legend = axes.legend(loc='best')
axes.set_title('time_spend_company')

fig2, axes2 = plt.subplots(1, 2, figsize=(10,10))
axes2[0].set_yticks(ar)
axes2[1].set_yticks(ar)

axes2[0].scatter(x,ar0, label=r"$left=0$")
axes2[1].scatter(x,ar1,label=r"$left=1$",color="orange")
legend = axes2[0].legend(loc='best')
legend2 = axes2[1].legend(loc='best')

axes2[0].set_title('time_spend_company, left=0')
axes2[1].set_title('time_spend_company, left=1')
# Out:
# rows in left=0:  8563 rows in left=1:  2675
# ar0, ar1  2674 2674
# max, min:  10 2
# ticks:  [2, 3, 4, 5, 6, 7, 8, 9]
# Text(0.5,1,'time_spend_company, left=1')

# %%
filen = "train.csv"
df = pd.read_csv(filen)

#left
attr_1 = 'satisfaction_level'
attr_2 = 'last_evaluation'
left_df = df['left']
df1 = df[attr_1]
df2 = df[attr_2]
left_0 = df[df['left']==0]
left_1 = df[df['left']==1]

sl0 = left_0[attr_1]
sl1 = left_1[attr_1]
# lim = 1000
# feature00 = sl0[:lim]
# feature01 = sl1[:lim]

amh0 = left_0[attr_2]
amh1 = left_1[attr_2]

# feature10 = amh0[:lim]
# feature11 = amh1[:lim]

# x = np.linspace(0,lim-1,lim)
fig, axes = plt.subplots(figsize=(10, 10))
# axes.set_yticks(ar_y)
# start, end = axes.get_xlim()

axes.scatter(sl0,amh0, label=r"$left=0$")
axes.scatter(sl1,amh1, label=r"$left=1$")


legend = axes.legend(loc='best')
axes.set_title('Comparison')


plt.xlabel(attr_1)
plt.ylabel(attr_2)
# plt.title('Rise i/n Sealevel')
# Out:
# Text(0,0.5,'last_evaluation')

# %%
filen = "train.csv"
df = pd.read_csv(filen)

# %%
f1 = "satisfaction_level"
f2 = "number_project"
# ax=df.plot(kind='scatter', x=f1, y=f2, color='DarkBlue', label='Group 1')
# plt.scatter(year, sea_levels, edgecolors='r')
